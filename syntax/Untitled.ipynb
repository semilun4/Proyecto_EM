# %% [markdown]
# Reiniciar kernel

# %%
import os
os._exit(00)

# %% [markdown]
# Librerías

# %%
# Librerias

# Path
import os

# Manipulacion
import pandas as pd
import numpy as np

# %% [markdown]
# ## Directorios y datos

# %%
PATH = "C:/Users/semir/Documents/CIMAT/Estadistica/Proyecto/"
if not PATH.endswith("/"):
    PATH = PATH + "/"

# Directorios
DATADIR = os.path.join(PATH, 'data/')
SYNTAXDIR = os.path.join(PATH, "syntax/")

# %%
RNPDNO_V3 = pd.read_csv(os.path.join(DATADIR, 'RNPDNO_V3.csv'), encoding='latin-1')
RNPDNO_V3
# Out:
#         IDX_REPORTE         CAMPO         SUBCAMPO  N_SUBCAMPO  \
# 0       01-000001-0  DESAPARECIDA  DATOS GENERALES           0
# 1       01-000002-0  DESAPARECIDA  DATOS GENERALES           0
# 2       01-000003-0  DESAPARECIDA  DATOS GENERALES           0
# 3       01-000004-0  DESAPARECIDA  DATOS GENERALES           0
# 4       01-000005-0  DESAPARECIDA  DATOS GENERALES           0
# ...             ...           ...              ...         ...
# 115508  21-001676-0  DESAPARECIDA  DATOS GENERALES           0
# 115509  21-001696-0  DESAPARECIDA  DATOS GENERALES           0
# 115510  21-001698-0  DESAPARECIDA  DATOS GENERALES           0
# 115511  21-001718-0  DESAPARECIDA  DATOS GENERALES           0
# 115512  21-001734-0  DESAPARECIDA  DATOS GENERALES           0
#
#                                               INSTITUCION  TOTAL  CON_DATO  \
# 0       COMISION LOCAL DE BUSQUEDA DE PERSONAS DEL EST...     22        18
# ...
